# %% [markdown]
# # Classifying Blood Smears with a Convolutional Neural Network
#
#
# <div style="background-color: #f0f8ff; border: 2px solid #4682b4; padding: 10px;">
# <a href="https://colab.research.google.com/github/Leolinen/TIF360/blob/main/HW2/blood_smears.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <strong>If using Colab/Kaggle:</strong> You need to uncomment the code in the cell below this one.
# </div>

# %%
# !pip install deeplay  # Uncomment if using Colab/Kaggle.
# Out:
# Requirement already satisfied: deeplay in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deeplay) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from deeplay) (3.10.0)
# Requirement already satisfied: torch>2.3 in /usr/local/lib/python3.12/dist-packages (from deeplay) (2.10.0+cpu)
# Requirement already satisfied: lightning in /usr/local/lib/python3.12/dist-packages (from deeplay) (2.6.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (from deeplay) (1.9.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from deeplay) (0.25.0+cpu)
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.12/dist-packages (from deeplay) (2.7.0)
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (from deeplay) (0.8.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from deeplay) (1.16.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from deeplay) (0.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from deeplay) (13.9.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from deeplay) (0.3.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (2025.3.0)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia->deeplay) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia->deeplay) (26.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning->deeplay) (6.0.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning->deeplay) (0.15.3)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning->deeplay) (4.67.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning->deeplay) (2.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->deeplay) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->deeplay) (2.20.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->deeplay) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->deeplay) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->deeplay) (0.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric->deeplay) (3.13.5)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric->deeplay) (5.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric->deeplay) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric->deeplay) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (1.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->deeplay) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->deeplay) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>2.3->deeplay) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>2.3->deeplay) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric->deeplay) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric->deeplay) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric->deeplay) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric->deeplay) (2026.2.25)

# %% [markdown]
# ## Loading the Malaria Dataset

# %%
import os
from torchvision.datasets.utils import _extract_zip, download_url

dataset_path = os.path.join(".", "blood_smears_dataset")
if not os.path.exists(dataset_path):
    url = "https://data.lhncbc.nlm.nih.gov/public/Malaria/cell_images.zip"
    download_url(url, ".")
    _extract_zip("cell_images.zip", dataset_path, None)
    os.remove("cell_images.zip")

# %% [markdown]
# ### Transforming the Images and Their Ground Thruth
#
# Define a transformation to resize the images to 28 by 28 pixels and convert them to PyTorch tensors (note that `ToTensor()` also normalizes their values between 0 and 1) ...

# %%
from torchvision.transforms import Compose, Resize, ToTensor

image_trans = Compose([Resize((28, 28)), ToTensor()])

# %% [markdown]
# ... define a transformation to make the target label equal to 0 for the uninfected cells and to 1 for the parasitized ones, converting it into a floating-point PyTorch tensor and adding a new dimension for batch processing ...

# %%
import torch

def label_trans(label):
    """Transform label."""
    return torch.tensor(1 - label).float().unsqueeze(-1)

# %% [markdown]
# ... and define a dataset that also makes these transformations.

# %%
from torchvision.datasets import ImageFolder

base_dir = os.path.join(dataset_path, "cell_images")
dataset = ImageFolder(base_dir, transform=image_trans,
                      target_transform=label_trans)

# %% [markdown]
# ### Splitting the Dataset and Defining the Data Loaders

# %%
train, test = torch.utils.data.random_split(dataset, [0.8, 0.2])

# %% [markdown]
# ... and define the data loaders.

# %%
train_loader = torch.utils.data.DataLoader(train, batch_size=32, shuffle=True)
test_loader = torch.utils.data.DataLoader(test, batch_size=256, shuffle=False)

# %%
import deeplay as dl

# %% [markdown]
# ### Plotting the ROC Curve
#
# Implement a function to plot the ROC curve ...

# %%
import torchmetrics as tm

def plot_roc(classifier, loader):
    """Plot ROC curve."""
    roc = tm.ROC(task="binary")
    for image, label in loader:
        roc.update(classifier(image), label.long())

    fig, ax = roc.plot(score=True)
    ax.grid(False)
    ax.axis("square")
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.legend(loc="center right")
    plt.show()

# %% [markdown]
# ... and use it to plot the performance of the classifier based on a dense neural network.

# %%
plot_roc(dnn_classifier, test_loader)

# %% [markdown]
# ## Classifying the Blood Smears with Convolutional Neural Networks
#
# Implement a convolutional neural network with a dense top ...

# %%
conv_base = dl.ConvolutionalNeuralNetwork(
    in_channels=3, hidden_channels=[16, 16, 32], out_channels=32,
)
conv_base.blocks[2].pool.configure(torch.nn.MaxPool2d, kernel_size=2)

connector = dl.Layer(torch.nn.AdaptiveAvgPool2d, output_size=1)

dense_top = dl.MultiLayerPerceptron(
    in_features=32, hidden_features=[], out_features=1,
    out_activation=torch.nn.Sigmoid,
)

cnn = dl.Sequential(conv_base, connector, dense_top)

# %% [markdown]
# ... print out its detailed architecture ...

# %%
print(cnn)
# Out:
# Sequential(
#   (0): ConvolutionalNeuralNetwork(
#     (blocks): LayerList(
#       (0): Conv2dBlock(
#         (layer): Layer[Conv2d](in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#       )
#       (1): Conv2dBlock(
#         (layer): Layer[Conv2d](in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#       )
#       (2): Conv2dBlock(
#         (pool): Layer[MaxPool2d](kernel_size=2)
#         (layer): Layer[Conv2d](in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[ReLU]()
#       )
#       (3): Conv2dBlock(
#         (layer): Layer[Conv2d](in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1)
#         (activation): Layer[Identity]()
#       )
#     )
#   )
#   (1): Layer[AdaptiveAvgPool2d](output_size=1)
#   (2): MultiLayerPerceptron(
#     (blocks): LayerList(
#       (0): LinearBlock(
#         (layer): Layer[Linear](in_features=32, out_features=1, bias=True)
#         (activation): Layer[Sigmoid]()
#       )
#     )
#   )
# )

# %% [markdown]
# ... compile it ...

# %%
cnn_classifier = dl.BinaryClassifier(
    model=cnn, optimizer=dl.RMSprop(lr=0.001),
).create()

# %% [markdown]
# ... and print out the compiled convolutional neural network.

# %%
print(cnn_classifier)
# Out:
# BinaryClassifier(
#   (loss): BCELoss()
#   (train_metrics): MetricCollection(
#     (BinaryAccuracy): BinaryAccuracy(),
#     prefix=train
#   )
#   (val_metrics): MetricCollection(
#     (BinaryAccuracy): BinaryAccuracy(),
#     prefix=val
#   )
#   (test_metrics): MetricCollection(
#     (BinaryAccuracy): BinaryAccuracy(),
#     prefix=test
#   )
#   (model): Sequential(
#     (0): ConvolutionalNeuralNetwork(
#       (blocks): LayerList(
#         (0): Conv2dBlock(
#           (layer): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#         )
#         (1): Conv2dBlock(
#           (layer): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#         )
#         (2): Conv2dBlock(
#           (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (layer): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): ReLU()
#         )
#         (3): Conv2dBlock(
#           (layer): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activation): Identity()
#         )
#       )
#     )
#     (1): AdaptiveAvgPool2d(output_size=1)
#     (2): MultiLayerPerceptron(
#       (blocks): LayerList(
#         (0): LinearBlock(
#           (layer): Linear(in_features=32, out_features=1, bias=True)
#           (activation): Sigmoid()
#         )
#       )
#     )
#   )
#   (optimizer): RMSprop[RMSprop](lr=0.001)
# )

# %% [markdown]
# ### Training the Convolutional Neural Network

# %%
cnn_trainer = dl.Trainer(max_epochs=5, accelerator="auto")
cnn_trainer.fit(cnn_classifier, train_loader)
# Out:
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ loss          │ BCELoss          │      0 │ train │     0 │
# │ 1 │ train_metrics │ MetricCollection │      0 │ train │     0 │
# │ 2 │ val_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 3 │ test_metrics  │ MetricCollection │      0 │ train │     0 │
# │ 4 │ model         │ Sequential       │ 16.7 K │ train │     0 │
# │ 5 │ optimizer     │ RMSprop          │      0 │ train │     0 │
# └───┴───────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 16.7 K
# Non-trainable params: 0
# Total params: 16.7 K
# Total estimated model params size (MB): 0
# Modules in train mode: 30
# Modules in eval mode: 0
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Training: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ### Testing the Convolutional Neural Network

# %%
cnn_trainer.test(cnn_classifier, test_loader)
# Out:
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ testBinaryAccuracy_epoch  │    0.9544547200202942     │
# │      test_loss_epoch      │    0.13974711298942566    │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss_epoch': 0.13974711298942566,
#   'testBinaryAccuracy_epoch': 0.9544547200202942}]

# %% [markdown]
# ### Plotting the ROC Curve

# %%
plot_roc(cnn_classifier, test_loader)

# %% [markdown]
# ### Checking the Values of the Filters
#
# The following code accesses the 32nd filter's weights in the first convolutional layer of the CNN. It navigates through the model's first module (`model[0]`), selects the initial block (`blocks[0]`), and then targets the layer's weights (`layer.weight[15]`).

# %%
filter = cnn_classifier.model[0].blocks[0].layer.weight[15]

print(filter)
# Out:
# tensor([[[-0.2288, -0.0287,  0.1329],
#          [-0.2414, -0.2099,  0.1228],
#          [ 0.1775,  0.0824, -0.0427]],
#
#         [[ 0.1381, -0.0527, -0.0071],
#          [ 0.0187,  0.1650,  0.1750],
#          [ 0.2723, -0.0747,  0.0206]],
#
#         [[-0.1057, -0.0183, -0.1392],
#          [-0.1264, -0.0927,  0.0214],
#          [ 0.1767,  0.0310, -0.0502]]], grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Visualizing the Activations of the Convolutional Layers
#
# Pick the image of an infected smear to then check the activations it produces on the last convolutional layer ...

# %%
from PIL import Image

im_ind = 0
image_filename = dataset.samples[im_ind][0]
image_hr = Image.open(image_filename)
image = image_trans(image_hr)

# %% [markdown]
# ... verify whether this image is of a parasitized cell ...

# %%
print(label_trans(dataset.targets[im_ind]))
# Out:
# tensor([1.])

# %% [markdown]
# ... define a function to visualize the activations ...

# %%
def plot_activations(activations, cols=8):
    """Visualize activations."""
    rows = -(activations.shape[0] // -cols)

    fig, axs = plt.subplots(rows, cols, figsize=(2 * cols, 2 * rows))
    for i, ax in enumerate(axs.ravel()):
        ax.axis("off")
        if i < activations.shape[0]:
            ax.imshow(activations[i].numpy())
            ax.set_title(i, fontsize=16)
    plt.show()

# %% [markdown]
# ... add a hook to access the activations in the forward pass ...

# %%
def hook_func(layer, input, output):
    """Hook for activations."""
    activations = output.detach().clone()
    plot_activations(activations[0])

for block in cnn_classifier.model[0].blocks:
    layer = block.layer
    handle_hook = layer.register_forward_hook(hook_func)

    try:
        pred = cnn_classifier.model(image.unsqueeze(0))
    except Exception as e:
        print(f"An error occurred during model prediction: {e}")
    finally:
        handle_hook.remove()

# %% [markdown]
# ### Visualizing the Heatmaps
#
# Use hooks to keep tracks also of the gradients in the backward pass ...

# %%
hookdata = {}

def fwd_hook_func(layer, input, output):
    """Forward hook function."""
    hookdata["activations"] = output.detach().clone()

def bwd_hook_func(layer, grad_input, grad_output):
    """Backward hook function."""
    hookdata["gradients"] = grad_output[0].detach().clone()

layer = cnn_classifier.model[0].blocks[3].layer
handle_fwd_hook = layer.register_forward_hook(fwd_hook_func)
handle_bwd_hook = layer.register_full_backward_hook(bwd_hook_func)

try:
    pred = cnn_classifier.model(image.unsqueeze(0))
    pred.sum().backward()
except Exception as e:
    print(f"An error occurred during model prediction: {e}")
finally:
    handle_fwd_hook.remove()
    handle_bwd_hook.remove()

# %% [markdown]
# ... calculate the heatmap combining activations and gradients ...

# %%
from torch.nn.functional import relu

activations = hookdata["activations"][0]
gradients = hookdata["gradients"][0]

pooled_gradients = gradients.mean(dim=[1, 2], keepdim=True)
heatmap = relu((pooled_gradients * activations).sum(0)).detach().numpy()

# %% [markdown]
# ... and plot the heatmap.

# %%
from numpy import array
from skimage.exposure import rescale_intensity
from skimage.transform import resize

rescaled_image = rescale_intensity(array(image_hr), out_range=(0, 1))
resized_heatmap = resize(heatmap, rescaled_image.shape, order=2)
rescaled_heatmap = rescale_intensity(resized_heatmap, out_range=(0.25, 1))

plt.figure(figsize=(12, 5))

plt.subplot(1, 3, 1)
plt.imshow(rescaled_image, interpolation="bilinear")
plt.title("Original image", fontsize=16)
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(rescaled_heatmap.mean(axis=-1), interpolation="bilinear")
plt.title("Heatmap with Grad-CAM", fontsize=16)
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(rescaled_image * rescaled_heatmap)
plt.title("Overlay", fontsize=16)
plt.axis("off")

plt.show()
